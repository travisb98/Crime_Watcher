# %%
import pandas as pd
import numpy as np
import requests
import json
import datetime as dt

# %%
query_url = "https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Police_Incidents_2021/FeatureServer/0/query?where=1%3D1&outFields=reportedDateTime,description,centerLong,centerLat&outSR=4326&f=json"

response = requests.get(query_url)

# %%
crime_data = response.json()

# %%
print(json.dumps(crime_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "attributes": {
#                 "centerLat": 44.98504707,
#                 "centerLong": -93.28019274,
#                 "description": "AUTOMOBILE THEFT              ",
#                 "reportedDateTime": 1609746060000
#             },
#             "geometry": {
#                 "x": -93.28018773714551,
#                 "y": 44.98504223806532
#             }
#         },
#         {
#             "attributes": {
#                 "centerLat": 44.96704546,
#                 "centerLong": -93.27932994,
#                 "description": "AUTOMOBILE THEFT              ",
#                 "reportedDateTime": 1609750800000
#             },
#             "geometry": {
#                 "x": -93.27932535447276,
#                 "y": 44.96703936199263
#             }
#         },
#         {
#             "attributes": {
#                 "centerLat": 45.0194712,
#                 "centerLong": -93.29685159,
# ...
